# %%
import pandas as pd

df = pd.read_csv("../data/data.csv")
print(df.head())
# Out:
#       name  age      city  salary
# 0    Alice   19   Chicago   50000
# 1      Bob   25  New York   72000
# 2  Charlie   17   Chicago   45000
# 3    David   32    Boston   88000
# 4      Eva   28   Seattle   64000

# %%
df = df[df['age'] > 20]

# %%
print(df.head())
# Out:
#      name  age      city  salary
# 1     Bob   25  New York   72000
# 3   David   32    Boston   88000
# 4     Eva   28   Seattle   64000
# 5   Frank   21    Austin   59000
# 7  Hannah   40   Chicago   99000
